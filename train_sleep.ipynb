# %%
# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
import pandas as pd

# %%
targets = ['202007', '202008', '202009', '202010', '202011', '202012', '202101', '202102', '202103']

# %%
for target in targets:
    df = pd.read_table(f'data/preprocessed/sleep_{target}.tsv', index_col=0)
    df.plot.scatter(x='hour', y='sleep_minutes', alpha=0.5, title=target)

# %%
dfs = map(lambda target: pd.read_table(f'data/preprocessed/sleep_{target}.tsv', index_col=0), targets)
